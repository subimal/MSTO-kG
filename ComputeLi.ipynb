# %%
# %load_ext autoreload
# %autoreload 2

# %%
from MSTOkG.MSTOOpt import *
from joblib import Parallel, delayed
import sys

# %%
dirname = "./testdata/"
prefix = 'MOBS'

# %%
# CreateMoleculesStdBasisSets(molecules='H Li Be B C N O F H2 LiH', 
#                             basissets=['6-31g', 'ccpvdz'], 
#                             forcedump=False, dirname=dirname)

# %%
# np.random.random(size=[2,3,4])

# %%
# choose your element
element = 'Li'
# get the default molecule in your basis
mol = moldict('sto-2g')[element]
# print the energy (HF and FCI)
Nmax = 10
# facs = [np.random.random(), 0]
tol = 1e-10
itermax=10
print(getEnergies(mol))
# Out:
# {'HF': -7.070820937427305, 'mol_HF': <pyscf.scf.rohf.ROHF object at 0x12225ee10>, 'CISD': -7.07110119993369, 'mol_CISD': <pyscf.ci.ucisd.UCISD object at 0x121e163c0>}

# %%
for passes in range(3):
    for k in range(2, 13):
        print(f"pass {passes}; k={k}")
        mol = FetchBestMol(element, k, dirname=dirname) 
        fname = os.path.join(dirname, f"{prefix}_{element}_msto-{k:02d}g.pickle")
        pop2, gen, en = OptimizeElement(mol, Nmax, fname, trials=20, tol=tol, trials_mu=20, trials_co=20)
        print()
        # print("Trying an aggressive refinement")
        # AggressiveRefinement(pop2[0][1], fname, trials=10, tol=tol, fci=True, itermax=10)
        # print()
# Out:
# pass 0; k=2
# [i:    4; M:   14; C:   19] Best:   -7.2020098 +/-            0 Ha, facs=[1.0561974150312714e-05, 0]]
# /opt/anaconda3/envs/science/lib/python3.12/site-packages/pyscf/ci/ucisd.py:881: RuntimeWarning: invalid value encountered in divide
#   t1a = eris.focka[:nocca,nocca:].conj() / eia_a
# /opt/anaconda3/envs/science/lib/python3.12/site-packages/pyscf/ci/ucisd.py:893: RuntimeWarning: invalid value encountered in divide
#   t2aa /= lib.direct_sum('ia+jb->ijab', eia_a, eia_a)
# [i:    6; M:   20; C:   19] Best:   -7.2020217 +/-            0 Ha, facs=[1.0422631224251522e-07, 0]]
# pass 0; k=3
# [i:    1; M:    5; C:   19] Best:   -7.3944786 +/-            0 Ha, facs=[0.02216445672498727, 0]]
# /opt/anaconda3/envs/science/lib/python3.12/site-packages/pyscf/ci/ucisd.py:881: RuntimeWarning: invalid value encountered in divide
#   t1a = eris.focka[:nocca,nocca:].conj() / eia_a
# /opt/anaconda3/envs/science/lib/python3.12/site-packages/pyscf/ci/ucisd.py:893: RuntimeWarning: invalid value encountered in divide
#   t2aa /= lib.direct_sum('ia+jb->ijab', eia_a, eia_a)
# [i:    6; M:   20; C:   19] Best:   -7.3945821 +/- 5.2978596e-06 Ha, facs=[6.713644263109592e-07, 0]
# pass 0; k=4
# [i:    6; M:   20; C:   19] Best:   -7.4320425 +/-            0 Ha, facs=[1.6525303867754082e-07, 0]]
# pass 0; k=5
# [i:    2; M:    8; C:   19] Best:   -7.4449912 +/-            0 Ha, facs=[0.007612944401403279, 0]]
# /opt/anaconda3/envs/science/lib/python3.12/site-packages/pyscf/ci/ucisd.py:881: RuntimeWarning: invalid value encountered in divide
#   t1a = eris.focka[:nocca,nocca:].conj() / eia_a
# /opt/anaconda3/envs/science/lib/python3.12/site-packages/pyscf/ci/ucisd.py:893: RuntimeWarning: invalid value encountered in divide
#   t2aa /= lib.direct_sum('ia+jb->ijab', eia_a, eia_a)
# [i:    5; M:   20; C:   19] Best:   -7.4451846 +/-            0 Ha, facs=[2.828902262239019e-07, 0]]]
# pass 0; k=6
# /opt/anaconda3/envs/science/lib/python3.12/site-packages/pyscf/ci/ucisd.py:881: RuntimeWarning: invalid value encountered in divide
#   t1a = eris.focka[:nocca,nocca:].conj() / eia_a
# /opt/anaconda3/envs/science/lib/python3.12/site-packages/pyscf/ci/ucisd.py:893: RuntimeWarning: invalid value encountered in divide
#   t2aa /= lib.direct_sum('ia+jb->ijab', eia_a, eia_a)
# [i:    2; M:    8; C:   19] Best:   -7.4508326 +/-            0 Ha, facs=[0.008932096998240373, 0]
# /opt/anaconda3/envs/science/lib/python3.12/site-packages/pyscf/ci/ucisd.py:881: RuntimeWarning: invalid value encountered in divide
#   t1a = eris.focka[:nocca,nocca:].conj() / eia_a
# /opt/anaconda3/envs/science/lib/python3.12/site-packages/pyscf/ci/ucisd.py:893: RuntimeWarning: invalid value encountered in divide
#   t2aa /= lib.direct_sum('ia+jb->ijab', eia_a, eia_a)
# [i:    3; M:   11; C:   19] Best:   -7.4508326 +/-            0 Ha, facs=[0.0005216918029804163, 0]]
# /opt/anaconda3/envs/science/lib/python3.12/site-packages/pyscf/ci/ucisd.py:881: RuntimeWarning: invalid value encountered in divide
#   t1a = eris.focka[:nocca,nocca:].conj() / eia_a
# /opt/anaconda3/envs/science/lib/python3.12/site-packages/pyscf/ci/ucisd.py:893: RuntimeWarning: invalid value encountered in divide
#   t2aa /= lib.direct_sum('ia+jb->ijab', eia_a, eia_a)
# [i:    5; M:   20; C:   19] Best:   -7.4510466 +/-            0 Ha, facs=[5.990387251357287e-07, 0]]]
# pass 0; k=7
# [i:    3; M:   20; C:   19] Best:   -7.4490986 +/-            0 Ha, facs=[0.0006481066651097733, 0]]
# pass 0; k=8
# [i:    1; M:    5; C:   19] Best:   -7.4500825 +/-            0 Ha, facs=[0.0929533036270989, 0]
# /opt/anaconda3/envs/science/lib/python3.12/site-packages/pyscf/ci/ucisd.py:881: RuntimeWarning: invalid value encountered in divide
#   t1a = eris.focka[:nocca,nocca:].conj() / eia_a
# /opt/anaconda3/envs/science/lib/python3.12/site-packages/pyscf/ci/ucisd.py:893: RuntimeWarning: invalid value encountered in divide
#   t2aa /= lib.direct_sum('ia+jb->ijab', eia_a, eia_a)
# [i:    6; M:   20; C:   19] Best:   -7.4500975 +/-            0 Ha, facs=[9.693289657172987e-07, 0]]
# pass 0; k=9
# [i:    1; M:   11; C:   19] Best:      -7.3997 +/- 3.3094935e-08 Ha, facs=[0.03510738202826289, 0]
# /opt/anaconda3/envs/science/lib/python3.12/site-packages/pyscf/ci/ucisd.py:881: RuntimeWarning: invalid value encountered in divide
#   t1a = eris.focka[:nocca,nocca:].conj() / eia_a
# /opt/anaconda3/envs/science/lib/python3.12/site-packages/pyscf/ci/ucisd.py:893: RuntimeWarning: invalid value encountered in divide
#   t2aa /= lib.direct_sum('ia+jb->ijab', eia_a, eia_a)
# [i:    3; M:   20; C:   19] Best:   -7.3999727 +/- 8.5935241e-09 Ha, facs=[0.0005382360382343462, 0]
# pass 0; k=10
# [i:    2; M:    8; C:   19] Best:    -7.450025 +/- 4.8313726e-09 Ha, facs=[0.006777455766011924, 0]
# /opt/anaconda3/envs/science/lib/python3.12/site-packages/pyscf/ci/ucisd.py:881: RuntimeWarning: invalid value encountered in divide
#   t1a = eris.focka[:nocca,nocca:].conj() / eia_a
# /opt/anaconda3/envs/science/lib/python3.12/site-packages/pyscf/ci/ucisd.py:893: RuntimeWarning: invalid value encountered in divide
#   t2aa /= lib.direct_sum('ia+jb->ijab', eia_a, eia_a)
# [i:    2; M:   11; C:   19] Best:   -7.4500384 +/-            0 Ha, facs=[0.004500417308579256, 0]]
# /opt/anaconda3/envs/science/lib/python3.12/site-packages/pyscf/ci/ucisd.py:881: RuntimeWarning: invalid value encountered in divide
#   t1a = eris.focka[:nocca,nocca:].conj() / eia_a
# /opt/anaconda3/envs/science/lib/python3.12/site-packages/pyscf/ci/ucisd.py:893: RuntimeWarning: invalid value encountered in divide
#   t2aa /= lib.direct_sum('ia+jb->ijab', eia_a, eia_a)
# [i:    5; M:   20; C:   19] Best:   -7.4500415 +/-            0 Ha, facs=[6.350282081182042e-06, 0]]
# pass 0; k=11
# [i:    2; M:   14; C:   19] Best:   -7.4158717 +/- 5.5125953e-05 Ha, facs=[0.005617069438254593, 0]]]
# /opt/anaconda3/envs/science/lib/python3.12/site-packages/pyscf/ci/ucisd.py:881: RuntimeWarning: invalid value encountered in divide
#   t1a = eris.focka[:nocca,nocca:].conj() / eia_a
# /opt/anaconda3/envs/science/lib/python3.12/site-packages/pyscf/ci/ucisd.py:893: RuntimeWarning: invalid value encountered in divide
#   t2aa /= lib.direct_sum('ia+jb->ijab', eia_a, eia_a)
# [i:    3; M:   20; C:   19] Best:   -7.4158843 +/-            0 Ha, facs=[0.00040749591315173637, 0]
# pass 0; k=12
# /opt/anaconda3/envs/science/lib/python3.12/site-packages/pyscf/ci/ucisd.py:881: RuntimeWarning: invalid value encountered in divide
#   t1a = eris.focka[:nocca,nocca:].conj() / eia_a
# /opt/anaconda3/envs/science/lib/python3.12/site-packages/pyscf/ci/ucisd.py:893: RuntimeWarning: invalid value encountered in divide
#   t2aa /= lib.direct_sum('ia+jb->ijab', eia_a, eia_a)
# [i:    5; M:   20; C:   19] Best:   -7.4488782 +/-            0 Ha, facs=[3.344735473682103e-07, 0]]]
# pass 1; k=2
# [i:    5; M:   17; C:   19] Best:   -7.2880118 +/-            0 Ha, facs=[9.252258354629828e-06, 0]]
# /opt/anaconda3/envs/science/lib/python3.12/site-packages/pyscf/ci/ucisd.py:881: RuntimeWarning: invalid value encountered in divide
#   t1a = eris.focka[:nocca,nocca:].conj() / eia_a
# /opt/anaconda3/envs/science/lib/python3.12/site-packages/pyscf/ci/ucisd.py:893: RuntimeWarning: invalid value encountered in divide
#   t2aa /= lib.direct_sum('ia+jb->ijab', eia_a, eia_a)
# [i:    6; M:   20; C:   19] Best:   -7.2880118 +/-            0 Ha, facs=[2.906579080758651e-07, 0]]
# pass 1; k=3
# /opt/anaconda3/envs/science/lib/python3.12/site-packages/pyscf/ci/ucisd.py:881: RuntimeWarning: invalid value encountered in divide
#   t1a = eris.focka[:nocca,nocca:].conj() / eia_a
# /opt/anaconda3/envs/science/lib/python3.12/site-packages/pyscf/ci/ucisd.py:893: RuntimeWarning: invalid value encountered in divide
#   t2aa /= lib.direct_sum('ia+jb->ijab', eia_a, eia_a)
# [i:    3; M:   11; C:   19] Best:   -7.3945838 +/-            0 Ha, facs=[0.00045652939999170914, 0]]
# /opt/anaconda3/envs/science/lib/python3.12/site-packages/pyscf/ci/ucisd.py:881: RuntimeWarning: invalid value encountered in divide
#   t1a = eris.focka[:nocca,nocca:].conj() / eia_a
# /opt/anaconda3/envs/science/lib/python3.12/site-packages/pyscf/ci/ucisd.py:893: RuntimeWarning: invalid value encountered in divide
#   t2aa /= lib.direct_sum('ia+jb->ijab', eia_a, eia_a)
# [i:    6; M:   20; C:   19] Best:   -7.3945861 +/-            0 Ha, facs=[3.1378332613146967e-07, 0]
# pass 1; k=4
# [i:    6; M:   20; C:   19] Best:   -7.4320427 +/-            0 Ha, facs=[1.564849753049874e-07, 0]]
# pass 1; k=5
# /opt/anaconda3/envs/science/lib/python3.12/site-packages/pyscf/ci/ucisd.py:881: RuntimeWarning: invalid value encountered in divide
#   t1a = eris.focka[:nocca,nocca:].conj() / eia_a
# /opt/anaconda3/envs/science/lib/python3.12/site-packages/pyscf/ci/ucisd.py:893: RuntimeWarning: invalid value encountered in divide
#   t2aa /= lib.direct_sum('ia+jb->ijab', eia_a, eia_a)
# [i:    0; M:    2; C:   19] Best:    -7.445186 +/-            0 Ha, facs=[0.5595174211100727, 0]]
# /opt/anaconda3/envs/science/lib/python3.12/site-packages/pyscf/ci/ucisd.py:881: RuntimeWarning: invalid value encountered in divide
#   t1a = eris.focka[:nocca,nocca:].conj() / eia_a
# /opt/anaconda3/envs/science/lib/python3.12/site-packages/pyscf/ci/ucisd.py:893: RuntimeWarning: invalid value encountered in divide
#   t2aa /= lib.direct_sum('ia+jb->ijab', eia_a, eia_a)
# [i:    4; M:   20; C:   19] Best:   -7.4456079 +/-            0 Ha, facs=[4.151107187851288e-05, 0]]]
# pass 1; k=6
# /opt/anaconda3/envs/science/lib/python3.12/site-packages/pyscf/ci/ucisd.py:881: RuntimeWarning: invalid value encountered in divide
#   t1a = eris.focka[:nocca,nocca:].conj() / eia_a
# /opt/anaconda3/envs/science/lib/python3.12/site-packages/pyscf/ci/ucisd.py:893: RuntimeWarning: invalid value encountered in divide
#   t2aa /= lib.direct_sum('ia+jb->ijab', eia_a, eia_a)
# [i:    2; M:    8; C:   19] Best:   -7.4510522 +/-            0 Ha, facs=[0.002866232611849264, 0]]
# /opt/anaconda3/envs/science/lib/python3.12/site-packages/pyscf/ci/ucisd.py:881: RuntimeWarning: invalid value encountered in divide
#   t1a = eris.focka[:nocca,nocca:].conj() / eia_a
# /opt/anaconda3/envs/science/lib/python3.12/site-packages/pyscf/ci/ucisd.py:893: RuntimeWarning: invalid value encountered in divide
#   t2aa /= lib.direct_sum('ia+jb->ijab', eia_a, eia_a)
# [i:    6; M:   20; C:   19] Best:   -7.4510545 +/-            0 Ha, facs=[6.033477185342073e-08, 0]]]
# pass 1; k=7
# [i:    5; M:   20; C:   19] Best:   -7.4493778 +/-            0 Ha, facs=[9.376019808978672e-06, 0]]
# pass 1; k=8
# /opt/anaconda3/envs/science/lib/python3.12/site-packages/pyscf/ci/ucisd.py:881: RuntimeWarning: invalid value encountered in divide
#   t1a = eris.focka[:nocca,nocca:].conj() / eia_a
# /opt/anaconda3/envs/science/lib/python3.12/site-packages/pyscf/ci/ucisd.py:893: RuntimeWarning: invalid value encountered in divide
#   t2aa /= lib.direct_sum('ia+jb->ijab', eia_a, eia_a)
# [i:    5; M:   20; C:   19] Best:   -7.4501145 +/-            0 Ha, facs=[7.356673243326115e-06, 0]]]
# pass 1; k=9
# /opt/anaconda3/envs/science/lib/python3.12/site-packages/pyscf/ci/ucisd.py:881: RuntimeWarning: invalid value encountered in divide
#   t1a = eris.focka[:nocca,nocca:].conj() / eia_a
# /opt/anaconda3/envs/science/lib/python3.12/site-packages/pyscf/ci/ucisd.py:893: RuntimeWarning: invalid value encountered in divide
#   t2aa /= lib.direct_sum('ia+jb->ijab', eia_a, eia_a)
# [i:    5; M:   20; C:   19] Best:   -7.4007553 +/- 0.00014003334 Ha, facs=[3.2977202156612574e-06, 0]
# pass 1; k=10
# [i:    6; M:   20; C:   19] Best:   -7.4500448 +/-            0 Ha, facs=[5.621628231307665e-07, 0]]]
# pass 1; k=11
# [i:    4; M:   20; C:   19] Best:   -7.4160232 +/-            0 Ha, facs=[7.944863809889768e-06, 0]]]
# pass 1; k=12
# [i:    2; M:   13; C:    0] Best:    -7.449128 +/-    5.4391357 Ha, facs=[0.004538280977815375, 0]0]
# /opt/anaconda3/envs/science/lib/python3.12/site-packages/pyscf/ci/ucisd.py:881: RuntimeWarning: invalid value encountered in divide
#   t1a = eris.focka[:nocca,nocca:].conj() / eia_a
# /opt/anaconda3/envs/science/lib/python3.12/site-packages/pyscf/ci/ucisd.py:893: RuntimeWarning: invalid value encountered in divide
#   t2aa /= lib.direct_sum('ia+jb->ijab', eia_a, eia_a)
# [i:    4; M:   20; C:   19] Best:   -7.4491525 +/- 4.209508e-08 Ha, facs=[7.279396592294748e-05, 0]]]
# pass 2; k=2
# /opt/anaconda3/envs/science/lib/python3.12/site-packages/pyscf/ci/ucisd.py:881: RuntimeWarning: invalid value encountered in divide
#   t1a = eris.focka[:nocca,nocca:].conj() / eia_a
# /opt/anaconda3/envs/science/lib/python3.12/site-packages/pyscf/ci/ucisd.py:893: RuntimeWarning: invalid value encountered in divide
#   t2aa /= lib.direct_sum('ia+jb->ijab', eia_a, eia_a)
# [i:    0; M:    2; C:    4] Best:   -7.2880118 +/-   0.66456943 Ha, facs=[0.36323222348763384, 0]

# %%
print("Trying a logical (agressive) refinement")
LogicalRefinement(element, Nmax, trials=20, tol=tol, trials_mu=50, trials_co=10, 
                  prefix = 'MOBS', dirname=dirname, ga_trial=False, itermax=25)
print()
