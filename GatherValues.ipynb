# %%
# %load_ext autoreload
# %autoreload 2

# %%
from MSTOkG.MSTOOpt import *
from joblib import Parallel, delayed
import sys

# %%
dirname = "./testdata/"

# %%
element = 'H'
PrintEnergies(element, dirname = "./testdata/", table=True, plot=True, prefix="MOBS", 
              save=False, ylim=[-0.5, -0.495])
# Out:
# Element: H (Last update: 2025-57-10/13/25  17:57)
# +--------+----------------------+----------------------+----------------------+
# | Basis  | HF                   | FCI                  | CISD                 |
# +--------+----------------------+----------------------+----------------------+
# | 6-31g  | -0.49823291072907006 | -0.49823291072907017 | -0.49823291072907006 |
# +--------+----------------------+----------------------+----------------------+
# | ccpvdz | -0.49927840341958307 | -0.49927840341958324 | -0.49927840341958285 |
# +--------+----------------------+----------------------+----------------------+
# +----+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+
# | k  | HF (STO)             | HF (MSTO)            | FCI (STO)            | FCI (MSTO)           | CISD (STO)           | CISD (MSTO)          |
# ...
